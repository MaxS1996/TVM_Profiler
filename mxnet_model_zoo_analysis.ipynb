# %%
import tvm
from tvm import te
import tvm.relay as relay
from tvm import rpc, autotvm, auto_scheduler
from tvm.autotvm.tuner import XGBTuner, GATuner, RandomTuner, GridSearchTuner
from tvm.contrib import utils, graph_executor as runtime
from tvm.contrib.download import download_testdata
from mxnet.gluon.model_zoo.vision import get_model
from PIL import Image
import numpy as np
import os
from tvm.contrib import utils

# %%
models = ['resnet18_v1',
        'resnet34_v1',
        'resnet50_v1',
        'resnet101_v1',
        'resnet152_v1',
        'resnet18_v2',
        'resnet34_v2',
        'resnet50_v2',
        'resnet101_v2',
        'resnet152_v2',
        'vgg11',
        'vgg13',
        'vgg16',
        'vgg19',
        'vgg11_bn',
        'vgg13_bn',
        'vgg16_bn',
        'vgg19_bn',
        'alexnet',
        'densenet121',
        'densenet161',
        'densenet169',
        'densenet201',
        'squeezenet1.0',
        'squeezenet1.1',
        'inceptionv3',
        'mobilenet1.0',
        'mobilenet0.75',
        'mobilenet0.5',
        'mobilenet0.25',
        'mobilenetv2_1.0',
        'mobilenetv2_0.75',
        'mobilenetv2_0.5',
        'mobilenetv2_0.25',
    ]

# %%
for model_name in models:
    block = get_model(model_name, pretrained=True)

# %%
dir(block)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_active',
#  '_alias',
#  '_backend',
#  '_backend_opts',
#  '_build_cache',
#  '_cached_graph',
#  '_cached_op',
#  '_cached_op_args',
#  '_call_cached_op',
#  '_callback',
#  '_check_container_with_block',
#  '_children',
#  '_clear_cached_op',
#  '_collect_params_with_prefix',
#  '_deferred_infer_shape',
#  '_empty_prefix',
#  '_flags',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_get_graph',
#  '_in_format',
#  '_infer_attrs',
#  '_make_features',
#  '_monitor_all',
#  '_name',
#  '_out_format',
#  '_params',
#  '_prefix',
#  '_reg_params',
#  '_scope',
#  'apply',
#  'cast',
#  'collect_params',
#  'export',
#  'features',
#  'forward',
#  'hybrid_forward',
#  'hybridize',
#  'infer_shape',
#  'infer_type',
#  'initialize',
#  'load',
#  'load_parameters',
#  'load_params',
#  'name',
#  'name_scope',
#  'optimize_for',
#  'output',
#  'params',
#  'prefix',
#  'register_child',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_op_hook',
#  'save',
#  'save_parameters',
#  'save_params',
#  'summary']

# %%
block.summary
# Out:
# <bound method Block.summary of VGG(
#   (features): HybridSequential(
#     (0): Conv2D(3 -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Activation(relu)
#     (2): Conv2D(64 -> 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Activation(relu)
#     (4): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False, global_pool=False, pool_type=max, layout=NCHW)
#     (5): Conv2D(64 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): Activation(relu)
#     (7): Conv2D(128 -> 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): Activation(relu)
#     (9): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False, global_pool=False, pool_type=max, layout=NCHW)
#     (10): Conv2D(128 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): Activation(relu)
#     (12): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): Activation(relu)
#     (14): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False, global_pool=False, pool_type=max, layout=NCHW)
#     (15): Conv2D(256 -> 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): Activation(relu)
#     (17): Conv2D(512 -> 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): Activation(relu)
#     (19): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False, global_pool=False, pool_type=max, layout=NCHW)
#     (20): Conv2D(512 -> 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): Activation(relu)
#     (22): Conv2D(512 -> 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): Activation(relu)
#     (24): MaxPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False, global_pool=False, pool_type=max, layout=NCHW)
#     (25): Dense(25088 -> 4096, Activation(relu))
#     (26): Dropout(p = 0.5, axes=())
#     (27): Dense(4096 -> 4096, Activation(relu))
#     (28): Dropout(p = 0.5, axes=())
#   )
#   (output): Dense(4096 -> 1000, linear)
# )>
